# %% [markdown]
# <a href="https://colab.research.google.com/github/Chimatanagagopal/DEEP-LEARNING_practice/blob/main/neural_network_approach_to_iris_dataset_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **An approach of Neural Network to predict Iris Species**
#
# This notebook explains about single layer perceptron and multilayer Neural Network (Deep NN) to predict the species of the Iris dataset.

# %%
# Keras
# tensorflow

# %%
#Import required libraries
import keras #library for neural network
import pandas as pd #loading data in table form
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
import numpy as np # linear algebra
from sklearn.preprocessing import normalize # machine learning algorithm library

# %%
#Reading data
data=pd.read_csv("/content/iris.csv")
# print("Describing the data: ",data.describe())
# print("Info of the data:",data.info())
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df = data.sample(n = 5)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 76            6.8          2.8           4.8          1.4       1
# 97            6.2          2.9           4.3          1.3       1
# 99            5.7          2.8           4.1          1.3       1
# 69            5.6          2.5           3.9          1.1       1
# 115           6.4          3.2           5.3          2.3       2

# %%
print("10 first samples of the dataset:",data.head(10))
print("10 last samples of the dataset:",data.tail(10))
# Out:
# 10 first samples of the dataset:      sepal_length  sepal_width  petal_length  petal_width species
# 89            5.5          2.5           4.0          1.3       1
# 81            5.5          2.4           3.7          1.0       1
# 35            5.0          3.2           1.2          0.2       0
# 121           5.6          2.8           4.9          2.0       2
# 95            5.7          3.0           4.2          1.2       1
# 8             4.4          2.9           1.4          0.2       0
# 40            5.0          3.5           1.3          0.3       0
# 28            5.2          3.4           1.4          0.2       0
# 142           5.8          2.7           5.1          1.9       2
# 77            6.7          3.0           5.0          1.7       1
# 10 last samples of the dataset:      sepal_length  sepal_width  petal_length  petal_width species
# 20            5.4          3.4           1.7          0.2       0
# ...

# %%
data["species"].unique()
# Out:
# array([0, 1, 2], dtype=object)

# %%
data.shape
# Out:
# (150, 5)

# %%
data.loc[data["species"]=="setosa","species"]=0
data.loc[data["species"]=="versicolor","species"]=1
data.loc[data["species"]=="virginica","species"]=2
print(data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2       0
# 1           4.9          3.0           1.4          0.2       0
# 2           4.7          3.2           1.3          0.2       0
# 3           4.6          3.1           1.5          0.2       0
# 4           5.0          3.6           1.4          0.2       0

# %%
data=data.iloc[np.random.permutation(len(data))]
print(data.head()) # shuffling the data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 89            5.5          2.5           4.0          1.3       1
# 81            5.5          2.4           3.7          1.0       1
# 35            5.0          3.2           1.2          0.2       0
# 121           5.6          2.8           4.9          2.0       2
# 95            5.7          3.0           4.2          1.2       1

# %% [markdown]
# Converting data to numpy array in order for processing

# %%
X=data.iloc[:,:4].values
y=data.iloc[:,4].values

print("Shape of X",X.shape)
print("Shape of y",y.shape)
print("Examples of X\n",X[:3])
print("Examples of y\n",y[:3])
# Out:
# Shape of X (150, 4)
# Shape of y (150,)
# Examples of X
#  [[5.5 2.5 4.  1.3]
#  [5.5 2.4 3.7 1. ]
#  [5.  3.2 1.2 0.2]]
# Examples of y
#  [1 1 0]

# %%
data.shape
# Out:
# (150, 5)

# %% [markdown]
# **Normalization**
#
# It can be seen from above that the feature of the first dataset has 6cm in Sepal Length, 3.4cm in Sepal Width, 4.5cm in Petal Length and 1.6cm in Petal Width. However, the range of the dataset may be different. Therefore, in order to maintain a good accuracy, the feature of each dataset must be normalized to a range of 0-1 for processing

# %%
X_normalized = normalize(X,axis=0)
print("Examples of X_normalised\n",X_normalized[:3])
# Out:
# Examples of X_normalised
#  [[0.07609697 0.06617903 0.07870418 0.07476947]
#  [0.07609697 0.06353187 0.07280136 0.05751497]
#  [0.06917906 0.08470916 0.02361125 0.01150299]]

# %%
#Creating train,test and validation data
'''
80% -- train data
20% -- test data
'''
total_length=len(data)
train_length=int(0.8*total_length)
test_length=int(0.2*total_length)

X_train=X_normalized[:train_length]
X_test=X_normalized[train_length:]
y_train=y[:train_length]
y_test=y[train_length:]

print("Length of train set x:",X_train.shape[0],"y:",y_train.shape[0])
print("Length of test set x:",X_test.shape[0],"y:",y_test.shape[0])
# Out:
# Length of train set x: 120 y: 120
# Length of test set x: 30 y: 30

# %%
#Neural network module
from keras.models import Sequential
from keras.layers import Dense,Activation
# from keras.utils import np_utils
import tensorflow as tf

# %%
y_train

# %%
#Change the label to one hot vector
'''
[0]--->[1 0 0]
[1]--->[0 1 0]
[2]--->[0 0 1]
'''
y_train=tf.keras.utils.to_categorical (y_train,num_classes=3)
y_test=tf.keras.utils.to_categorical (y_test,num_classes=3)
print("Shape of y_train",y_train.shape)
print("Shape of y_test",y_test.shape)
# Out:
# Shape of y_train (120, 3)
# Shape of y_test (30, 3)

# %%
# # multi-class classification
# # # define the keras model
model = Sequential()

model.add(Dense(32, input_dim=4, activation="relu"))  # 1st hidden layer
model.add(Dense(64, activation="relu")) # 2nd hidden layer
model.add(Dense(128, activation="relu")) # 3rd hidden layer
model.add(Dense(256, activation="relu"))

model.add(Dense(3, activation='softmax')) # output layer
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='categorical_crossentropy',# error
              optimizer='adam',# gradient descent
              metrics=['accuracy'] # accuracy
              )

# %%
# # Regression
# model = Sequential()
# model.add(Dense(32, input_dim = 4,activation = 'relu'))
# model.add(Dense(64, activation = 'relu'))
# model.add(Dense(128, activation = 'relu'))
# model.add(Dense(256, activation = 'relu'))
# model.add(Dense(1)) # output layer

# %%
# two-class classification
# model = Sequential()
# model.add(Dense(32,input_dim=4,activation = 'relu'))
# model.add(Dense(64, activation = 'relu'))
# model.add(Dense(128, activation = 'relu'))
# model.add(Dense(256, activation = 'relu'))

# model.add(Dense(1,activation='sigmoid'))

# %%
# multi-class classification
# model = Sequential()
# model.add(Dense(32,input_dim=4,activation = 'relu'))
# model.add(Dense(64, activation = 'relu'))
# model.add(Dense(128, activation = 'relu'))
# model.add(Dense(256, activation = 'relu'))

# model.add(Dense(3,activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# model.compile(loss='categorical_crossentropy',metrics=['accuracy', "recall"])

# %%
model.fit(X_train,y_train,
          validation_data=(X_test,y_test),
          batch_size=30,
          epochs=30)
# Out:
# Epoch 1/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.3333 - loss: 1.0969 - val_accuracy: 0.3333 - val_loss: 1.0905
# Epoch 2/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4667 - loss: 1.0876 - val_accuracy: 0.6333 - val_loss: 1.0828
# Epoch 3/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6750 - loss: 1.0775 - val_accuracy: 0.6333 - val_loss: 1.0701
# Epoch 4/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6750 - loss: 1.0627 - val_accuracy: 0.6333 - val_loss: 1.0523
# Epoch 5/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6750 - loss: 1.0420 - val_accuracy: 0.6333 - val_loss: 1.0275
# Epoch 6/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6750 - loss: 1.0119 - val_accuracy: 0.6333 - val_loss: 0.9920
# Epoch 7/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6750 - loss: 0.9702 - val_accuracy: 0.6333 - val_loss: 0.9453
# Epoch 8/30
# ...

# %%
prediction=model.predict(X_test)
length=len(prediction)

y_label=np.argmax(y_test,axis=1)
predict_label=np.argmax(prediction,axis=1)

accuracy=np.sum(y_label==predict_label)/length * 100
print("Accuracy of the dataset",accuracy )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Accuracy of the dataset 96.66666666666667
